# %%
import os
import torch
import numpy as np
import pickle
import time
import random
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from generation_manager import GeneratorManager

# %%
curr_model_path = 'ckpt/model_TEST_noEuc.pth' # model checkpoint
# Saving only state_dict:
#torch.save(model.state_dict(), model_state_dict_path)
#model_state_dict_path = load_model_path + 'model_only_state_dict_v0Last.pth'
#print('Model state dict saved')

# %%
def save_sequences(predicted, predicted_stopped, tokens_probs_all, name):
    data_dir = "data_halogenase/generation/"
    query = name
    os.makedirs(data_dir, exist_ok=True)
    
    predicted_data_file = os.path.join(data_dir, "predicted_data_" + query + ".p")
    with open(predicted_data_file, "wb") as file:
        pickle.dump(predicted, file)

    predicted_stopped_data_file = os.path.join(data_dir, "predicted_stopped_data_" + query + ".p")
    with open(predicted_stopped_data_file, "wb") as file:
        pickle.dump(predicted_stopped, file)

    tokens_probs_all_file = os.path.join(data_dir, "tokens_prob_data_" + query + ".p")
    with open(tokens_probs_all_file, "wb") as file:
        pickle.dump(tokens_probs_all, file)

# %%
# GENERATION parameters
temperature = 0.9
penalty = 1.2
top_p = 0.5
np.random.seed(1337)
torch.manual_seed(1337)
random.seed(1337)
torch.cuda.manual_seed_all(1337)

generator = GeneratorManager(curr_model_path, penalty=penalty, top_p=top_p, temperature=temperature)
# Out:
# MODEL SIZE:
# 1280
# Found PyTorch checkpoint at  ckpt/model_TEST_noEuc.pth
# GPU aviable. Previous checkpoint loaded in GPU

# %%
def generation(name, keys):
    predicted = []
    predicted_stopped = []
    # true_tokens_index_in_probs_all = []
    tokens_probs_all = []
    # true_value = []
    seq_number = 0
    #for entry in random_selection:
    while seq_number <= 1000:
        # input_seq = entry['sequence']['metadata']['sequence']
        # FOR TESTIG the code:
        # input_seq = input_seq[0:24]
        input_seq = ''
        
        # if no tax keys:
        tax_lineage = keys
        offset = 0
        
        #print('generating sequences...')
        #start_time = time.time()
        res, tokens_generated_stopped, tokens_prob = generator.generation_complete_sequence_new(input_seq, tax_lineage, offset)
        #end_time = time.time()
        #elapsed_time = end_time - start_time
        #print(f"Done. Time taken: {elapsed_time} seconds.")
    
        tokens_probs_all.append(tokens_prob)
        
        # print("Input: ", input_seq)
        # print("Res: ", res)
        # true_value.append(input_seq)
        # true_tokens_index_in_prob = []
        # true_tokens_index_in_probs_all.append(true_tokens_index_in_prob)
        # tokens_probs_all.append(tokens_prob)
        # print('input_offset should be nothing: ', input_seq[:offset])
        predicted.append(input_seq[:offset] + res)
        if tokens_generated_stopped:
            for tmp_seq in tokens_generated_stopped:
                predicted_stopped.append(input_seq[:offset] + tmp_seq)
    
        seq_number += 1
        print('hello, this is seq_number', seq_number)
        print('hello, this is seq_number module: ', seq_number%10)
        
        # FOR TESTIG:
    
        
        if (seq_number%20) == 0:
            print('the model has generated: ', seq_number , ' sequences')
            print('saving sequences')
            save_sequences(predicted, predicted_stopped, tokens_probs_all, name)
    
            
    print('GENERATION ENDED')

# %%
generation('p0_50_percent_penalty_0_key_only_hydro', [0])
# Out:
# hello, this is seq_number 1
# hello, this is seq_number module:  1
# hello, this is seq_number 2
# hello, this is seq_number module:  2
# hello, this is seq_number 3
# hello, this is seq_number module:  3
# hello, this is seq_number 4
# hello, this is seq_number module:  4
# hello, this is seq_number 5
# hello, this is seq_number module:  5
# hello, this is seq_number 6
# hello, this is seq_number module:  6
# hello, this is seq_number 7
# hello, this is seq_number module:  7
# hello, this is seq_number 8
# hello, this is seq_number module:  8
# hello, this is seq_number 9
# hello, this is seq_number module:  9
# hello, this is seq_number 10
# hello, this is seq_number module:  0
# hello, this is seq_number 11
# hello, this is seq_number module:  1
# hello, this is seq_number 12
# hello, this is seq_number module:  2
# hello, this is seq_number 13
# hello, this is seq_number module:  3
# hello, this is seq_number 14
# hello, this is seq_number module:  4
# hello, this is seq_number 15
# hello, this is seq_number module:  5
# hello, this is seq_number 16
# hello, this is seq_number module:  6
# hello, this is seq_number 17
# hello, this is seq_number module:  7
# hello, this is seq_number 18
# hello, this is seq_number module:  8
# hello, this is seq_number 19
# hello, this is seq_number module:  9
# hello, this is seq_number 20
# hello, this is seq_number module:  0
# the model has generated:  20  sequences
# saving sequences
# hello, this is seq_number 21
# hello, this is seq_number module:  1
# hello, this is seq_number 22
# hello, this is seq_number module:  2
# hello, this is seq_number 23
# hello, this is seq_number module:  3
# hello, this is seq_number 24
# hello, this is seq_number module:  4
# hello, this is seq_number 25
# hello, this is seq_number module:  5
# hello, this is seq_number 26
# hello, this is seq_number module:  6
# hello, this is seq_number 27
# hello, this is seq_number module:  7
# hello, this is seq_number 28
# hello, this is seq_number module:  8
# hello, this is seq_number 29
# hello, this is seq_number module:  9
# hello, this is seq_number 30
# hello, this is seq_number module:  0
# hello, this is seq_number 31
# hello, this is seq_number module:  1
# hello, this is seq_number 32
# hello, this is seq_number module:  2
# hello, this is seq_number 33
# hello, this is seq_number module:  3
# hello, this is seq_number 34
# hello, this is seq_number module:  4
# hello, this is seq_number 35
# hello, this is seq_number module:  5
# hello, this is seq_number 36
# hello, this is seq_number module:  6
# hello, this is seq_number 37
# hello, this is seq_number module:  7
# hello, this is seq_number 38
# hello, this is seq_number module:  8
# hello, this is seq_number 39
# hello, this is seq_number module:  9
# hello, this is seq_number 40
# hello, this is seq_number module:  0
# the model has generated:  40  sequences
# saving sequences
# hello, this is seq_number 41
# hello, this is seq_number module:  1
# hello, this is seq_number 42
# hello, this is seq_number module:  2
# hello, this is seq_number 43
# hello, this is seq_number module:  3
# hello, this is seq_number 44
# hello, this is seq_number module:  4
# hello, this is seq_number 45
# hello, this is seq_number module:  5
# hello, this is seq_number 46
# hello, this is seq_number module:  6
# hello, this is seq_number 47
# hello, this is seq_number module:  7
# hello, this is seq_number 48
# hello, this is seq_number module:  8
# hello, this is seq_number 49
# hello, this is seq_number module:  9
# hello, this is seq_number 50
# hello, this is seq_number module:  0
# hello, this is seq_number 51
# hello, this is seq_number module:  1
# hello, this is seq_number 52
# hello, this is seq_number module:  2
# hello, this is seq_number 53
# hello, this is seq_number module:  3
# hello, this is seq_number 54
# hello, this is seq_number module:  4
# hello, this is seq_number 55
# hello, this is seq_number module:  5
# hello, this is seq_number 56
# hello, this is seq_number module:  6
# hello, this is seq_number 57
# hello, this is seq_number module:  7
# hello, this is seq_number 58
# hello, this is seq_number module:  8
# hello, this is seq_number 59
# hello, this is seq_number module:  9
# hello, this is seq_number 60
# hello, this is seq_number module:  0
# the model has generated:  60  sequences
# saving sequences
# hello, this is seq_number 61
# hello, this is seq_number module:  1
# hello, this is seq_number 62
# hello, this is seq_number module:  2
# hello, this is seq_number 63
# hello, this is seq_number module:  3
# hello, this is seq_number 64
# hello, this is seq_number module:  4
# hello, this is seq_number 65
# hello, this is seq_number module:  5
# hello, this is seq_number 66
# hello, this is seq_number module:  6
# hello, this is seq_number 67
# hello, this is seq_number module:  7
# hello, this is seq_number 68
# hello, this is seq_number module:  8
# hello, this is seq_number 69
# hello, this is seq_number module:  9
# hello, this is seq_number 70
# hello, this is seq_number module:  0
# hello, this is seq_number 71
# hello, this is seq_number module:  1
# hello, this is seq_number 72
# hello, this is seq_number module:  2
# hello, this is seq_number 73
# hello, this is seq_number module:  3
# hello, this is seq_number 74
# hello, this is seq_number module:  4
# hello, this is seq_number 75
# hello, this is seq_number module:  5
# hello, this is seq_number 76
# hello, this is seq_number module:  6
# hello, this is seq_number 77
# hello, this is seq_number module:  7
# hello, this is seq_number 78
# hello, this is seq_number module:  8
# hello, this is seq_number 79
# hello, this is seq_number module:  9
# hello, this is seq_number 80
# hello, this is seq_number module:  0
# the model has generated:  80  sequences
# saving sequences
# hello, this is seq_number 81
# hello, this is seq_number module:  1
# hello, this is seq_number 82
# hello, this is seq_number module:  2
# hello, this is seq_number 83
# hello, this is seq_number module:  3
# hello, this is seq_number 84
# hello, this is seq_number module:  4
# hello, this is seq_number 85
# hello, this is seq_number module:  5
# hello, this is seq_number 86
# hello, this is seq_number module:  6
# hello, this is seq_number 87
# hello, this is seq_number module:  7
# hello, this is seq_number 88
# hello, this is seq_number module:  8
# hello, this is seq_number 89
# hello, this is seq_number module:  9
# hello, this is seq_number 90
# hello, this is seq_number module:  0
# hello, this is seq_number 91
# hello, this is seq_number module:  1
# hello, this is seq_number 92
# hello, this is seq_number module:  2
# hello, this is seq_number 93
# hello, this is seq_number module:  3
# hello, this is seq_number 94
# hello, this is seq_number module:  4
# hello, this is seq_number 95
# hello, this is seq_number module:  5
# hello, this is seq_number 96
# hello, this is seq_number module:  6
# hello, this is seq_number 97
# hello, this is seq_number module:  7
# hello, this is seq_number 98
# hello, this is seq_number module:  8
# hello, this is seq_number 99
# hello, this is seq_number module:  9
# hello, this is seq_number 100
# hello, this is seq_number module:  0
# the model has generated:  100  sequences
# saving sequences
# hello, this is seq_number 101
# hello, this is seq_number module:  1
# hello, this is seq_number 102
# hello, this is seq_number module:  2
# hello, this is seq_number 103
# hello, this is seq_number module:  3
# hello, this is seq_number 104
# hello, this is seq_number module:  4
# hello, this is seq_number 105
# hello, this is seq_number module:  5
# hello, this is seq_number 106
# hello, this is seq_number module:  6
# hello, this is seq_number 107
# hello, this is seq_number module:  7
# hello, this is seq_number 108
# hello, this is seq_number module:  8
# hello, this is seq_number 109
# hello, this is seq_number module:  9
# hello, this is seq_number 110
# hello, this is seq_number module:  0
# hello, this is seq_number 111
# hello, this is seq_number module:  1
# hello, this is seq_number 112
# hello, this is seq_number module:  2
# hello, this is seq_number 113
# hello, this is seq_number module:  3
# hello, this is seq_number 114
# hello, this is seq_number module:  4
# hello, this is seq_number 115
# hello, this is seq_number module:  5
# hello, this is seq_number 116
# hello, this is seq_number module:  6
# hello, this is seq_number 117
# hello, this is seq_number module:  7
# hello, this is seq_number 118
# hello, this is seq_number module:  8
# hello, this is seq_number 119
# hello, this is seq_number module:  9
# hello, this is seq_number 120
# hello, this is seq_number module:  0
# the model has generated:  120  sequences
# saving sequences
# hello, this is seq_number 121
# hello, this is seq_number module:  1
# hello, this is seq_number 122
# hello, this is seq_number module:  2
# hello, this is seq_number 123
# hello, this is seq_number module:  3
# hello, this is seq_number 124
# hello, this is seq_number module:  4
# hello, this is seq_number 125
# hello, this is seq_number module:  5
# hello, this is seq_number 126
# hello, this is seq_number module:  6
# hello, this is seq_number 127
# hello, this is seq_number module:  7
# hello, this is seq_number 128
# hello, this is seq_number module:  8
# hello, this is seq_number 129
# hello, this is seq_number module:  9
# hello, this is seq_number 130
# hello, this is seq_number module:  0
# hello, this is seq_number 131
# hello, this is seq_number module:  1
# hello, this is seq_number 132
# hello, this is seq_number module:  2
# hello, this is seq_number 133
# hello, this is seq_number module:  3
# hello, this is seq_number 134
# hello, this is seq_number module:  4
# hello, this is seq_number 135
# hello, this is seq_number module:  5
# hello, this is seq_number 136
# hello, this is seq_number module:  6
# hello, this is seq_number 137
# hello, this is seq_number module:  7
# hello, this is seq_number 138
# hello, this is seq_number module:  8
# hello, this is seq_number 139
# hello, this is seq_number module:  9
# hello, this is seq_number 140
# hello, this is seq_number module:  0
# the model has generated:  140  sequences
# saving sequences
# hello, this is seq_number 141
# hello, this is seq_number module:  1
# hello, this is seq_number 142
# hello, this is seq_number module:  2
# hello, this is seq_number 143
# hello, this is seq_number module:  3
# hello, this is seq_number 144
# hello, this is seq_number module:  4
# hello, this is seq_number 145
# hello, this is seq_number module:  5
# hello, this is seq_number 146
# hello, this is seq_number module:  6
# hello, this is seq_number 147
# hello, this is seq_number module:  7
# hello, this is seq_number 148
# hello, this is seq_number module:  8
# hello, this is seq_number 149
# hello, this is seq_number module:  9
# hello, this is seq_number 150
# hello, this is seq_number module:  0
# hello, this is seq_number 151
# hello, this is seq_number module:  1
# hello, this is seq_number 152
# hello, this is seq_number module:  2
# hello, this is seq_number 153
# hello, this is seq_number module:  3
# hello, this is seq_number 154
# hello, this is seq_number module:  4
# hello, this is seq_number 155
# hello, this is seq_number module:  5
# hello, this is seq_number 156
# hello, this is seq_number module:  6
# hello, this is seq_number 157
# hello, this is seq_number module:  7
# hello, this is seq_number 158
# hello, this is seq_number module:  8
# hello, this is seq_number 159
# hello, this is seq_number module:  9
# hello, this is seq_number 160
# hello, this is seq_number module:  0
# the model has generated:  160  sequences
# saving sequences
# hello, this is seq_number 161
# hello, this is seq_number module:  1
# hello, this is seq_number 162
# hello, this is seq_number module:  2
# hello, this is seq_number 163
# hello, this is seq_number module:  3
# hello, this is seq_number 164
# hello, this is seq_number module:  4
# hello, this is seq_number 165
# hello, this is seq_number module:  5
# hello, this is seq_number 166
# hello, this is seq_number module:  6
# hello, this is seq_number 167
# hello, this is seq_number module:  7
# hello, this is seq_number 168
# hello, this is seq_number module:  8
# hello, this is seq_number 169
# hello, this is seq_number module:  9
# hello, this is seq_number 170
# hello, this is seq_number module:  0
# hello, this is seq_number 171
# hello, this is seq_number module:  1
# hello, this is seq_number 172
# hello, this is seq_number module:  2
# hello, this is seq_number 173
# hello, this is seq_number module:  3
# hello, this is seq_number 174
# hello, this is seq_number module:  4
# hello, this is seq_number 175
# hello, this is seq_number module:  5
# hello, this is seq_number 176
# hello, this is seq_number module:  6
# hello, this is seq_number 177
# hello, this is seq_number module:  7
# hello, this is seq_number 178
# hello, this is seq_number module:  8
# hello, this is seq_number 179
# hello, this is seq_number module:  9
# hello, this is seq_number 180
# hello, this is seq_number module:  0
# the model has generated:  180  sequences
# saving sequences
# hello, this is seq_number 181
# hello, this is seq_number module:  1
# hello, this is seq_number 182
# hello, this is seq_number module:  2
# hello, this is seq_number 183
# hello, this is seq_number module:  3
# hello, this is seq_number 184
# hello, this is seq_number module:  4
# hello, this is seq_number 185
# hello, this is seq_number module:  5
# hello, this is seq_number 186
# hello, this is seq_number module:  6
# hello, this is seq_number 187
# hello, this is seq_number module:  7
# hello, this is seq_number 188
# hello, this is seq_number module:  8
# hello, this is seq_number 189
# hello, this is seq_number module:  9
# hello, this is seq_number 190
# hello, this is seq_number module:  0
# hello, this is seq_number 191
# hello, this is seq_number module:  1
# hello, this is seq_number 192
# hello, this is seq_number module:  2
# hello, this is seq_number 193
# hello, this is seq_number module:  3
# hello, this is seq_number 194
# hello, this is seq_number module:  4
# hello, this is seq_number 195
# hello, this is seq_number module:  5
# hello, this is seq_number 196
# hello, this is seq_number module:  6
# hello, this is seq_number 197
# hello, this is seq_number module:  7
# hello, this is seq_number 198
# hello, this is seq_number module:  8
# hello, this is seq_number 199
# hello, this is seq_number module:  9
# hello, this is seq_number 200
# hello, this is seq_number module:  0
# the model has generated:  200  sequences
# saving sequences
# hello, this is seq_number 201
# hello, this is seq_number module:  1
# hello, this is seq_number 202
# hello, this is seq_number module:  2
# hello, this is seq_number 203
# hello, this is seq_number module:  3
# hello, this is seq_number 204
# hello, this is seq_number module:  4
# hello, this is seq_number 205
# hello, this is seq_number module:  5
# hello, this is seq_number 206
# hello, this is seq_number module:  6
# hello, this is seq_number 207
# hello, this is seq_number module:  7
# hello, this is seq_number 208
# hello, this is seq_number module:  8
# hello, this is seq_number 209
# hello, this is seq_number module:  9
# hello, this is seq_number 210
# hello, this is seq_number module:  0
# hello, this is seq_number 211
# hello, this is seq_number module:  1
# hello, this is seq_number 212
# hello, this is seq_number module:  2
# hello, this is seq_number 213
# hello, this is seq_number module:  3
# hello, this is seq_number 214
# hello, this is seq_number module:  4
# hello, this is seq_number 215
# hello, this is seq_number module:  5
# hello, this is seq_number 216
# hello, this is seq_number module:  6
# hello, this is seq_number 217
# hello, this is seq_number module:  7
# hello, this is seq_number 218
# hello, this is seq_number module:  8
# hello, this is seq_number 219
# hello, this is seq_number module:  9
# hello, this is seq_number 220
# hello, this is seq_number module:  0
# the model has generated:  220  sequences
# saving sequences
# hello, this is seq_number 221
# hello, this is seq_number module:  1
# hello, this is seq_number 222
# hello, this is seq_number module:  2
# hello, this is seq_number 223
# hello, this is seq_number module:  3

# %%
generation('p0_50_percent_penalty_0_key_0_1', [0, 1])

# %%
generation('p0_50_percent_penalty_0_key_0_2', [0, 2])

# %%
generation('p0_50_percent_penalty_0_key_0_3', [0, 3])
